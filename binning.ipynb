# %% [markdown]
# ## Importing the dataset

# %%
import pandas as pd
import numpy as np

dataframe = pd.read_csv('cleaned_exams.csv')
dataframe
# Out:
#      student  gender race/ethnicity parental level of education         lunch  \
# 0          0    male        group A                 high school      standard
# 1          1  female        group D            some high school  free/reduced
# 2          2    male        group E                some college  free/reduced
# 3          3    male        group B                 high school      standard
# 4          4    male        group E          associate's degree      standard
# ..       ...     ...            ...                         ...           ...
# 994      995    male        group C                 high school      standard
# 995      996    male        group D          associate's degree  free/reduced
# 996      997  female        group C            some high school  free/reduced
# 997      998  female        group C                some college      standard
# 998      999    male        group A                some college      standard
#
# ...

# %% [markdown]
# ## Binning

# %%
bins = [0, 72, 76, 80, 84, 88, 92, 96, 101]
labels = ['Failure', 'Passing', 'Below Average', 'Average', 'Above Average', 'Good', 'Superior', 'Excellent']

math_labels = pd.cut(dataframe['math score'], bins=bins, labels=labels, right=False)
reading_labels = pd.cut(dataframe['reading score'], bins=bins, labels=labels, right=False)
writing_labels = pd.cut(dataframe['writing score'], bins=bins, labels=labels, right=False)

dataframe.insert(7, 'math grade', math_labels)
dataframe.insert(9, 'reading grade', reading_labels)
dataframe.insert(11, 'writing grade', writing_labels)

dataframe
# Out:
#      student  gender race/ethnicity parental level of education         lunch  \
# 0          0    male        group A                 high school      standard
# 1          1  female        group D            some high school  free/reduced
# 2          2    male        group E                some college  free/reduced
# 3          3    male        group B                 high school      standard
# 4          4    male        group E          associate's degree      standard
# ..       ...     ...            ...                         ...           ...
# 994      995    male        group C                 high school      standard
# 995      996    male        group D          associate's degree  free/reduced
# 996      997  female        group C            some high school  free/reduced
# 997      998  female        group C                some college      standard
# 998      999    male        group A                some college      standard
#
# ...

# %%
dataframe.to_csv('graded_exams.csv', index=False)
